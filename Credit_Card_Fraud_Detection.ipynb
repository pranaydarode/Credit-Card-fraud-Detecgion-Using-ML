# %% [markdown]
# <a href="https://colab.research.google.com/github/pranaydarode/Credit-Card-fraud-Detection-Using-ML/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data to Pandas Dataframe

# %%
credit_card_data = pd.read_csv('/content/credit_card_data.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 253500  156282.0  0.218778  2.127147 -0.913767  5.047434  0.539264 -0.442585
# 253501  156283.0 -0.013939  0.815212 -0.305154 -1.037117  1.070352 -0.022552
# 253502  156283.0  1.056413 -1.749109 -2.585717  0.398554  0.222439 -0.194947
# 253503  156285.0  2.156224 -1.148549 -1.851902 -2.028743  1.342173  3.515969
# 253504  156285.0 -1.016503  0.782572 -0.722561  0.805216  2.004004  1.358744
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 253500  0.257464  0.488943 -1.731597  ... -0.379459 -1.109785  0.256910
# 253501  0.839901  0.018731 -0.067494  ... -0.286580 -0.752399 -0.102248
# 253502  1.011298 -0.304179  0.388653  ...  0.430509  0.131367 -0.507749
# 253503 -1.558541  0.937717 -0.263942  ...  0.023066 -0.109653  0.426833
# 253504  0.576182  0.801618 -0.919811  ...  0.323296  1.047230 -0.043480
#
# ...

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253505 entries, 0 to 253504
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    253505 non-null  float64
#  1   V1      253505 non-null  float64
#  2   V2      253505 non-null  float64
#  3   V3      253505 non-null  float64
#  4   V4      253505 non-null  float64
#  5   V5      253505 non-null  float64
#  6   V6      253505 non-null  float64
#  7   V7      253505 non-null  float64
#  8   V8      253505 non-null  float64
#  9   V9      253505 non-null  float64
#  10  V10     253505 non-null  float64
#  11  V11     253505 non-null  float64
#  12  V12     253505 non-null  float64
#  13  V13     253505 non-null  float64
#  14  V14     253505 non-null  float64
#  15  V15     253505 non-null  float64
#  16  V16     253505 non-null  float64
#  17  V17     253505 non-null  float64
#  18  V18     253505 non-null  float64
#  19  V19     253505 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data=credit_card_data.fillna('')

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    253038
# 1.0       466
#             1
# Name: Class, dtype: int64

# %% [markdown]
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction
#
# Unbalanced Data

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (253038, 31)
# (466, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count     253038.0
# unique     31320.0
# top            1.0
# freq       12100.0
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     466.0
# unique    242.0
# top         1.0
# freq      112.0
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
# <ipython-input-21-4fe90e2a08db>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   credit_card_data.groupby('Class').mean()
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0     86313.79332 -0.022485 -0.026768  0.103480  0.012823 -0.028295
# 1.0     76150.95279 -4.960433  3.768371 -7.205388  4.627674 -3.358554
#        156285.00000 -1.016503  0.782572 -0.722561  0.805216  2.004004
#
#              V6        V7        V8        V9  ...       V16       V17  \
# Class                                          ...
# 0.0    0.019120 -0.003560  0.000909  0.005429  ...  0.005981  0.021395
# 1.0   -1.387638 -5.788415  0.620053 -2.632096  ... -4.272574 -6.908653
#        1.358744  0.576182  0.801618 -0.919811  ... -2.258782  1.417776
#
# ...

# %% [markdown]
# Under-Sampling
#
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions
#
# Number of Fraudulent Transactions --> 466

# %%
legit_sample = legit.sample(n=466)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 148469   89927.0  1.925881 -0.040931 -1.569666  1.496209  0.171590 -0.425190
# 117751   74795.0  1.133871  0.338611  0.819999  2.330151 -0.144588  0.228717
# 164439  116718.0 -0.215350  0.448418  1.133534 -0.322960  0.020723 -0.581180
# 212057  138695.0  2.030396 -0.826222 -2.872131 -1.365891  1.165245  0.604663
# 153840  100341.0 -0.431772  0.670348 -0.445506  0.080966 -1.211844  1.072223
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 148469 -0.105853  0.087267  0.833435  ...  0.052689  0.293178 -0.034717
# 117751 -0.191951  0.038563 -0.460583  ... -0.101210 -0.409168 -0.045896
# 164439  0.030723  0.053293  0.599273  ...  0.167915  0.633569  0.101939
# 212057  0.241720 -0.063326 -1.430298  ...  0.020381  0.641038 -0.058128
# 153840  2.069026 -1.175973  1.520056  ...  0.474136 -0.587278  0.751720
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 251881  155542.0  1.868226  1.363077 -1.994934  4.173516  1.239751 -0.746186
# 251891  155548.0  1.878230  1.325630 -2.333469  4.233151  1.355184 -0.853508
# 251904  155554.0 -1.040067  3.106703 -5.409027  3.109903 -0.887237 -2.497522
# 252124  155662.0 -1.928613  4.601506 -7.124053  5.716088  1.026579 -3.189073
# 252774  155965.0 -1.201398  4.864535 -8.328823  7.652399 -0.167445 -2.767695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 251881  0.572731 -0.131235 -1.551839  ... -0.301001 -0.818972  0.206812
# 251891  0.716025 -0.164910 -1.502345  ... -0.152131 -0.360736  0.043414
# 251904 -2.073347  0.639818 -3.013331  ...  0.773961  0.214868 -0.184233
# 252124 -2.261897  1.185096 -4.441942  ...  0.602291 -0.541287 -0.354639
# 252774 -3.176421  1.623279 -4.367228  ...  0.532320 -0.556913  0.192444
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    466
# 1.0    466
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
# <ipython-input-28-586b59598b15>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_dataset.groupby('Class').mean()
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    86922.504292 -0.029278 -0.081862 -0.039672  0.029589 -0.073407
# 1.0    76150.952790 -4.960433  3.768371 -7.205388  4.627674 -3.358554
#
#              V6        V7        V8        V9  ...       V16       V17  \
# Class                                          ...
# 0.0    0.021602 -0.009186 -0.046064  0.020980  ...  0.073386  0.022294
# 1.0   -1.387638 -5.788415  0.620053 -2.632096  ... -4.272574 -6.908653
#
#             V18       V19       V20       V21       V22       V23       V24  \
# Class
# 0.0    0.048196  0.033416  0.022497  0.011766  0.018266 -0.006390  0.023653
# ...

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 148469   89927.0  1.925881 -0.040931 -1.569666  1.496209  0.171590 -0.425190
# 117751   74795.0  1.133871  0.338611  0.819999  2.330151 -0.144588  0.228717
# 164439  116718.0 -0.215350  0.448418  1.133534 -0.322960  0.020723 -0.581180
# 212057  138695.0  2.030396 -0.826222 -2.872131 -1.365891  1.165245  0.604663
# 153840  100341.0 -0.431772  0.670348 -0.445506  0.080966 -1.211844  1.072223
# ...          ...       ...       ...       ...       ...       ...       ...
# 251881  155542.0  1.868226  1.363077 -1.994934  4.173516  1.239751 -0.746186
# 251891  155548.0  1.878230  1.325630 -2.333469  4.233151  1.355184 -0.853508
# 251904  155554.0 -1.040067  3.106703 -5.409027  3.109903 -0.887237 -2.497522
# 252124  155662.0 -1.928613  4.601506 -7.124053  5.716088  1.026579 -3.189073
# 252774  155965.0 -1.201398  4.864535 -8.328823  7.652399 -0.167445 -2.767695
#
# ...

# %%
print(Y)
# Out:
# 148469    0.0
# 117751    0.0
# 164439    0.0
# 212057    0.0
# 153840    0.0
#          ...
# 251881    1.0
# 251891    1.0
# 251904    1.0
# 252124    1.0
# 252774    1.0
# Name: Class, Length: 932, dtype: float64

# %%
Y = Y.astype(float)
print(Y)
# Out:
# 148469    0.0
# 117751    0.0
# 164439    0.0
# 212057    0.0
# 153840    0.0
#          ...
# 251881    1.0
# 251891    1.0
# 251904    1.0
# 252124    1.0
# 252774    1.0
# Name: Class, Length: 932, dtype: float64

# %% [markdown]
# Splitting into test and train data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y)

# %%
print(X.shape, X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (932, 30) (745, 30) (187, 30) (745,) (187,)

# %% [markdown]
# Logistic Regression Model Deyployment

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit( X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9369127516778524

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9358288770053476
